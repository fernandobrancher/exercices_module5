# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_enem = pd.read_csv('MICRODADOS_ENEM_2019_SAMPLE_43278.csv')
# df = pd.read_csv('MICRODADOS_ENEM_2019_SAMPLE_43278.csv',usecols=) #seleciona quais colunas voce pretende utilizar
df_enem
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0       190001004661    2019                  1506138                Redenção
# 1       190001004674    2019                  1504208                  Marabá
# 2       190001004722    2019                  1501402                   Belém
# 3       190001004735    2019                  1507300      São Félix do Xingu
# 4       190001004776    2019                  1500800              Ananindeua
# ...              ...     ...                      ...                     ...
# 127375  190006120035    2019                  3142700             Montalvânia
# 127376  190006120036    2019                  2902807         Barra da Estiva
# 127377  190006120037    2019                  2927408                Salvador
# 127378  190006120060    2019                  2930709            Simões Filho
# 127379  190006120170    2019                  3106200          Belo Horizonte
#
# ...

# %% [markdown]
# ##### Limpando o dataset
#
# - Verificando se há colunas ou linhas vazias

# %%
df_enem[df_enem.isnull().all(axis=1)]
# não há linhas com todos valores nulos
# Out:
# Empty DataFrame
# ...

# %%
# linhas com pelo menos um valor nulo
df_enem[df_enem.isnull().any(axis=1)]
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0       190001004661    2019                  1506138                Redenção
# 1       190001004674    2019                  1504208                  Marabá
# 2       190001004722    2019                  1501402                   Belém
# 3       190001004735    2019                  1507300      São Félix do Xingu
# 4       190001004776    2019                  1500800              Ananindeua
# ...              ...     ...                      ...                     ...
# 127373  190006119987    2019                  2925204                  Pojuca
# 127374  190006119995    2019                  2927408                Salvador
# 127377  190006120037    2019                  2927408                Salvador
# 127378  190006120060    2019                  2930709            Simões Filho
# 127379  190006120170    2019                  3106200          Belo Horizonte
#
# ...

# %%
df_enem[df_enem.duplicated()]
# não há linhas duplicads
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# - filtrar colunas : pegar só quem fez, depois pegar notas e fazer média
# - definir perfil dos aprovados ~~medicina~~ (considerando 800 pontos como media)
# - considerar aqui perfil de quem tem media superior a 800
# - porcentagem, sexo, raca, etnia, estado ....

# %%
df_enem.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        ...
#        'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024',
#        'Q025'],
#       dtype='object', length=136)>

# %%
# see all columns
for col_name in df_enem.columns: 
    print(col_name)
# Out:
# NU_INSCRICAO
# NU_ANO
# CO_MUNICIPIO_RESIDENCIA
# NO_MUNICIPIO_RESIDENCIA
# CO_UF_RESIDENCIA
# SG_UF_RESIDENCIA
# NU_IDADE
# TP_SEXO
# TP_ESTADO_CIVIL
# TP_COR_RACA
# TP_NACIONALIDADE
# CO_MUNICIPIO_NASCIMENTO
# NO_MUNICIPIO_NASCIMENTO
# CO_UF_NASCIMENTO
# SG_UF_NASCIMENTO
# TP_ST_CONCLUSAO
# TP_ANO_CONCLUIU
# TP_ESCOLA
# TP_ENSINO
# IN_TREINEIRO
# CO_ESCOLA
# CO_MUNICIPIO_ESC
# NO_MUNICIPIO_ESC
# CO_UF_ESC
# SG_UF_ESC
# TP_DEPENDENCIA_ADM_ESC
# TP_LOCALIZACAO_ESC
# TP_SIT_FUNC_ESC
# IN_BAIXA_VISAO
# IN_CEGUEIRA
# IN_SURDEZ
# IN_DEFICIENCIA_AUDITIVA
# IN_SURDO_CEGUEIRA
# IN_DEFICIENCIA_FISICA
# IN_DEFICIENCIA_MENTAL
# IN_DEFICIT_ATENCAO
# IN_DISLEXIA
# IN_DISCALCULIA
# IN_AUTISMO
# IN_VISAO_MONOCULAR
# IN_OUTRA_DEF
# IN_GESTANTE
# IN_LACTANTE
# IN_IDOSO
# IN_ESTUDA_CLASSE_HOSPITALAR
# IN_SEM_RECURSO
# IN_BRAILLE
# IN_AMPLIADA_24
# IN_AMPLIADA_18
# IN_LEDOR
# IN_ACESSO
# IN_TRANSCRICAO
# IN_LIBRAS
# IN_TEMPO_ADICIONAL
# IN_LEITURA_LABIAL
# IN_MESA_CADEIRA_RODAS
# ...

# %%
df_enem['TP_PRESENCA_CN'].value_counts()
# Out:
# 1    92758
# 0    34570
# 2       52
# Name: TP_PRESENCA_CN, dtype: int64

# %% [markdown]
# Pela análise acima "acredito" que 1 seja compareceu e 0 não compareceu.
# Filtrando apenas os alunos que compareceram a todas as provas.

# %%
df_filtro_presenca = df_enem.loc[(df_enem['TP_PRESENCA_CN']==1) & (df_enem['TP_PRESENCA_CH']==1) & (df_enem['TP_PRESENCA_LC']==1)
                        & (df_enem['TP_PRESENCA_MT']==1)].copy()
df_filtro_presenca
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0       190001004661    2019                  1506138                Redenção
# 2       190001004722    2019                  1501402                   Belém
# 3       190001004735    2019                  1507300      São Félix do Xingu
# 4       190001004776    2019                  1500800              Ananindeua
# 5       190001004841    2019                  1503606                Itaituba
# ...              ...     ...                      ...                     ...
# 127373  190006119987    2019                  2925204                  Pojuca
# 127375  190006120035    2019                  3142700             Montalvânia
# 127376  190006120036    2019                  2902807         Barra da Estiva
# 127378  190006120060    2019                  2930709            Simões Filho
# 127379  190006120170    2019                  3106200          Belo Horizonte
#
# ...

# %%
df_filtro_presenca['NOTA_FINAL'] = df_filtro_presenca[['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO']].mean(axis=1)
df_filtro_presenca
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0       190001004661    2019                  1506138                Redenção
# 2       190001004722    2019                  1501402                   Belém
# 3       190001004735    2019                  1507300      São Félix do Xingu
# 4       190001004776    2019                  1500800              Ananindeua
# 5       190001004841    2019                  1503606                Itaituba
# ...              ...     ...                      ...                     ...
# 127373  190006119987    2019                  2925204                  Pojuca
# 127375  190006120035    2019                  3142700             Montalvânia
# 127376  190006120036    2019                  2902807         Barra da Estiva
# 127378  190006120060    2019                  2930709            Simões Filho
# 127379  190006120170    2019                  3106200          Belo Horizonte
#
# ...

# %%
df_media_alta = df_filtro_presenca.loc[(df_filtro_presenca['NOTA_FINAL']>769)]
nota_max = df_media_alta['NOTA_FINAL'].max()
nota_min = df_media_alta['NOTA_FINAL'].min()
print(f'Range das Médias dos Alunos Selecionados: de {nota_min} a {nota_max}')
# Out:
# Range das Médias dos Alunos Selecionados: de 769.3 a 832.82

# %%
plt.figure(figsize=(5,3))
df_media_alta['NOTA_FINAL'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ##### Análise dos Alunos que obtiveram nota superior a 769

# %%
plt.figure(figsize=(5,3))

df_media_alta['TP_SEXO'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='TP_SEXO'>

# %%
perc_homem = (df_media_alta['TP_SEXO'].value_counts()[0]/df_media_alta['TP_LINGUA'].count())*100
perc_homem
# Out:
# 57.89473684210527

# %%
plt.figure(figsize=(5,3))
df_media_alta['TP_COR_RACA'].value_counts().plot(kind='bar')
# 0 -> Não declarado ||| 1 -> Branca ||| 2	->  Preta ||| 3	-> Parda ||| 4 -> Amarela ||| 5 -> Indígena
# Out:
# <Axes: >

# %%
plt.figure(figsize=(5,3))
df_media_alta['NU_IDADE'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.figure(figsize=(5,3))
df_media_alta['SG_UF_NASCIMENTO'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Tipo da Escola: 1:Não Respondeu ||| 2:Pública ||| 3:Privada

plt.figure(figsize=(5,3))
df_media_alta['TP_ESCOLA'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(5,3))
df_media_alta['TP_ST_CONCLUSAO'].value_counts().plot(kind='bar')
df_media_alta['TP_ST_CONCLUSAO'].value_counts()
# pelo dicionário do dataset: 1: Já concluiu ----- 2: Vai concluir no ano do exame (2019) ------ 3: Vai concluir após o ano do exame (2019)
# Out:
# 1    94
# 2    35
# 3     4
# Name: TP_ST_CONCLUSAO, dtype: int64

# %%
plt.figure(figsize=(5,3))
df_media_alta['TP_LINGUA'].value_counts().plot(kind='bar')
perc_ingles = (df_media_alta['TP_LINGUA'].value_counts()[0]/df_media_alta['TP_LINGUA'].count())*100
perc_ingles
# Out:
# 93.23308270676691

# %%
#criano a coluna de Nota Final para o dataframe das pessoas que compareceram a todas provas
df_filtro_presenca['NOTA_FINAL2'] = df_filtro_presenca[['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO']].mean(axis=1)

# %%
# Q006 - Renda familiar
df_filtro_presenca.groupby('Q006')['NOTA_FINAL2'].mean()
# análise: quanto maior for a renda -> maior a media dos alunos que participaram
# Out:
# Q006
# A    474.004641
# B    482.746673
# C    503.465648
# D    521.695165
# E    530.277175
# F    547.889076
# G    554.296901
# H    573.621471
# I    579.439165
# J    587.401010
# K    598.674775
# L    608.811299
# M    602.868509
# N    614.042101
# O    619.270155
# P    633.213170
# Q    640.405957
# Name: NOTA_FINAL2, dtype: float64

# %%
# Q006 - Renda familiar
df_media_alta.groupby('Q006')['NOTA_FINAL'].mean()
#a mesma lógica acima não se aplica aos alunos de alto rendimento
# Out:
# Q006
# A    787.900000
# C    773.320000
# D    780.365000
# E    769.820000
# F    783.288000
# G    785.353333
# H    779.840000
# I    793.478333
# J    781.324000
# K    794.480000
# L    785.555000
# M    782.870000
# N    783.367692
# O    789.035789
# P    783.345455
# Q    785.198000
# Name: NOTA_FINAL, dtype: float64

# %% [markdown]
# ####  Resumo dos Dados Analisados:

# %% [markdown]
# - mais da metade são do sexo masculino, mas não há uma disparidade muito grande (57% homens)
# - raça: maioria expressiva de brancos, seguido por pardos
# - a idade desses alunos é um sua grande maioria dos 17 aos 20, cruzando com os dados de conclusão, é possível ver que a grande maioria (70%) já havia concluido o E.M., provavelmente alunos de cursinho, apenas 26% são concluintes do ano do exame
# - em sua grande maioria são de SP e MG (pode ter a ver com os estados serem populosos, teria que ver proporção)
# - mais de 93% fez a prova de línguas estrangeira como inglês
# - 5 alunos apresentam deficit de atenção, nenhuma outra deficiência foi declarada
# - não há alunas gestantes ou lactantes nesse recorte
