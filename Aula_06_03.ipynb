# %%
print('teste')
# Out:
# teste

# %%
import pandas as pd
import plotly.graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import plotly.graph_objects as go
#
# ModuleNotFoundError: No module named 'plotly'

# %%
# !pip install plotly
# Out:
# ...
#      ---------------------------------------- 0.0/15.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.2 MB ? eta -:--:--
#      --------------------------------------- 0.1/15.2 MB 975.2 kB/s eta 0:00:16
#      --------------------------------------- 0.1/15.2 MB 655.4 kB/s eta 0:00:24
#      --------------------------------------- 0.1/15.2 MB 847.9 kB/s eta 0:00:18
#      --------------------------------------- 0.1/15.2 MB 847.9 kB/s eta 0:00:18
#       -------------------------------------- 0.2/15.2 MB 731.4 kB/s eta 0:00:21
#       -------------------------------------- 0.2/15.2 MB 731.4 kB/s eta 0:00:21
#       -------------------------------------- 0.3/15.2 MB 682.7 kB/s eta 0:00:22
#       -------------------------------------- 0.3/15.2 MB 682.7 kB/s eta 0:00:22
#       -------------------------------------- 0.3/15.2 MB 655.5 kB/s eta 0:00:23
#       -------------------------------------- 0.3/15.2 MB 655.0 kB/s eta 0:00:23
# ...
